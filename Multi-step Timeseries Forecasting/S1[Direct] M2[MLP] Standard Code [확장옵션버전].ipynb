# %% [markdown]
# # ==================================================
# # S1 (Direct Strategy)
# # M2 (MLP)
# # Standard Code _ Version 1.0 / KISLAB @ Kookmin University
# # ==================================================

# %% [markdown]
# # Basic Options (for Extended Experiment)

# %%
# 기본 설정값
SMCODE = "S1M2"    # S1(Direct Strategy) + M2(MLP) 를 위한 Standard Code
PDCODE = "ONI"     # 품종코드
MDCODE = "MLP"     # 모델코드
PDNAME = "Onion"   # 품종명(영문)
VARS = 2           # 확장변수 사용여부 (1: 가격만 사용, 2: 거래량 추가사용)

# 학습 기본변수 설정
DROPOUT = 0.1   # Dropout 비율
EPOCH = 200    # 총 목표 학습횟수
PATIENCE = 10   # 학습 조기 중지를 위한 early stopping 옵션
BATCH = 32

# Special Option 설정
FRAC = 1    # 검증기간 데이터 중 학습 데이터에 추가로 포함시킬 데이터의 비중 (0~1)
IRANGE = 365   # 가격 데이터를 입력으로 사용할 때 최대 총 며칠치 데이터를 사용할 것인지에 대한 옵션
SPLIT = 210    # 이 값을 0으로 설정할 경우, validation 수행하지 않음
WINSOR = 10   # 이상치 제거를 위한 Winsorizing 기준 설정 (단위: 퍼센트 / 이 값이 0일 경우, 이상치 제거 안함)

#BASEDATE = '2021-01-01'   # 검증용 데이터의 시작 시점 (D1을 위한 설정)
#USEDATE = '2021-12-31'    # 전체 사용할 데이터의 마지막 시점 (D1을 위한 설정)
BASEDATE = '2022-01-01'   # 검증용 데이터의 시작 시점 (D2를 위한 설정)
USEDATE = '2022-07-29'    # 전체 사용할 데이터의 마지막 시점 (D2를 위한 설정)

SELECTED = [30, 90, 180, 270, 365]    # 예측모델을 개발할 선택 시점
NSEL = len(SELECTED)    # 예측모델을 개발할 선택 시점의 총 갯수


# ============= 데이터셋 로드 ================  

# Ignore the warnings
import warnings
#warnings.filterwarnings('always')
warnings.filterwarnings('ignore')
import pandas as pd

#load data
raw = pd.read_excel('(140103-220728)양파(양파(일반)).xlsx', usecols=['일자', '품종', '거래량(톤)', '도매가격(원/kg)'])
# raw = raw[raw['품종']=='양파(일반)']

#create 'datetime' column
if '일자' in raw.columns:
    raw['일자'] = pd.to_datetime(raw['일자'])
    raw['DateTime'] = pd.to_datetime(raw['일자'])

#set datetime to index 
if raw.index.dtype == 'int64':
    raw.set_index('DateTime',inplace=True)

raw.drop (['품종', '일자'], axis=1, inplace=True)
raw.columns = ['Price', 'Volume']
for i in range(0, raw.shape[0]):
    raw['Volume'][i] = raw['Volume'][i].replace(',','')
raw['Volume'] = raw['Volume'].astype('float32')

#fill missing date & values
raw.asfreq('D')[raw.asfreq('D').isnull().sum(axis=1) > 0]
raw = raw.asfreq('D', method='ffill')

# %% [markdown]
# # Load Library

# %%
# System related and data input controls
import os

# Data manipulation, visualization and useful functions
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format
pd.options.display.max_rows = 50
pd.options.display.max_columns = 40
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

# Modeling algorithms
# General(Statistics/Econometrics)
from sklearn import preprocessing
import statsmodels.api as sm
import statsmodels.tsa.api as smt
import statsmodels.formula.api as smf

# Regression
from lightgbm import LGBMRegressor as lgb
import lightgbm as lgb

# Evaluation metrics for regression
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error
import joblib
import tensorflow as tf

# %%
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Dense, Activation, Flatten, Dropout, BatchNormalization
from tensorflow.keras.models import load_model
import tensorflow as tf
from keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam, SGD, Nadam
import keras

# %% [markdown]
# # Feature Engineering code

# %%
### Feature engineering of all
def feature_engineering(raw):
    if 'datetime' in raw.columns:
        raw['datetime'] = pd.to_datetime(raw['datetime'])
        raw['DateTime'] = pd.to_datetime(raw['datetime'])

    if raw.index.dtype == 'int64':
        raw.set_index('DateTime', inplace=True)

    raw = raw.asfreq('D', method='ffill')
    raw['Price'].fillna(method='ffill',inplace=True)

    result = sm.tsa.seasonal_decompose(raw['Price'], model='additive')
    Y_trend = pd.DataFrame(result.trend)
    Y_trend.fillna(method='ffill', inplace=True)
    Y_trend.fillna(method='bfill', inplace=True)
    Y_trend.columns = ['Price_trend']
    Y_seasonal = pd.DataFrame(result.seasonal)
    Y_seasonal.fillna(method='ffill', inplace=True)
    Y_seasonal.fillna(method='bfill', inplace=True)
    Y_seasonal.columns = ['Price_seasonal']
    pd.concat([raw, Y_trend, Y_seasonal], axis=1).isnull().sum()
    if 'Price_trend' not in raw.columns:
        if 'Price_seasonal' not in raw.columns:
            raw = pd.concat([raw, Y_trend, Y_seasonal], axis=1)


    # STL분해 중 잔차 구하기
    result = sm.tsa.seasonal_decompose(raw['Price'], model='additive',period=30,two_sided=False)
    Y_remainder = pd.DataFrame(result.resid)
    Y_remainder.fillna(method='ffill', inplace=True)
    Y_remainder.fillna(method='bfill', inplace=True)
    Y_remainder.columns = ['Price_resid']
    raw = pd.concat([raw, Y_remainder], axis=1)
    
    #시간 변수 만들기
    raw['year'] = pd.DatetimeIndex(raw.index).year
    raw['month'] = pd.DatetimeIndex(raw.index).month
    raw['day'] = pd.DatetimeIndex(raw.index).day
    raw['day_of_year'] = pd.DatetimeIndex(raw.index).dayofyear
    raw['week_of_year'] = pd.DatetimeIndex(raw.index).weekofyear
    raw['season'] = raw.month%12 // 3 + 1
    raw['Quarter'] = (raw.index.quarter)
    raw['Quarter_ver2'] =(raw['Quarter'] + (raw.year - raw.year.min()) * 4)
    if 'Quarter' in raw.columns:
        if 'Quarter_Dummy' not in ['_'.join(col.split('_')[:2]) for col in raw.columns]:
            raw = pd.concat([raw, pd.get_dummies(raw['Quarter'], 
                                                 prefix='Quarter_Dummy', drop_first=True)], axis=1)
            del raw['Quarter']
    month_in_year = 12
    raw['month_sin'] = np.sin(2*np.pi*raw.month/month_in_year)
    raw['month_cos'] = np.cos(2*np.pi*raw.month/month_in_year)
    
    days_in_month = 30
    raw['day_sin'] = np.sin(2*np.pi*raw.day/days_in_month)
    raw['day_cos'] = np.cos(2*np.pi*raw.day/days_in_month)
    
    days_in_year = 365
    raw['day_of_year_sin'] = np.sin(2*np.pi*raw.day_of_year/days_in_year)
    raw['day_of_year_cos'] = np.cos(2*np.pi*raw.day_of_year/days_in_year)
    
    weeks_in_year = 52.1429
    raw['week_of_year_sin'] = np.sin(2*np.pi*raw.week_of_year/weeks_in_year)
    raw['week_of_year_cos'] = np.cos(2*np.pi*raw.week_of_year/weeks_in_year)
    
    seasons_in_year = 4
    raw['season_sin'] = np.sin(2*np.pi*raw.season/seasons_in_year)
    raw['season_cos'] = np.cos(2*np.pi*raw.season/seasons_in_year)
    raw.drop(['day', 'day_of_year', 'week_of_year', 'season'],axis=1,inplace=True)
    
    #가격 관련 변수 추가
    raw['rolling_mean_t30'] = raw['Price'].transform(lambda x: x.ewm(span=30,min_periods=1,adjust=True,ignore_na=False).mean())
    raw['rolling_mean_t90'] = raw['Price'].transform(lambda x: x.ewm(span=90,min_periods=1,adjust=True,ignore_na=False).mean())
    raw['rolling_mean_t180'] = raw['Price'].transform(lambda x: x.ewm(span=180,min_periods=1,adjust=True,ignore_na=False).mean())
    raw['rolling_mean_t270'] = raw['Price'].transform(lambda x: x.ewm(span=270,min_periods=1,adjust=True,ignore_na=False).mean())
    raw['rolling_mean_t365'] = raw['Price'].transform(lambda x: x.ewm(span=365,min_periods=1,adjust=True,ignore_na=False).mean())
    
    #for a in range(1,366):
    #    raw[f'Price_lag{a}'] = raw['Price'].shift(a)
    #    raw[f'Price_lag{a}'].fillna(0,inplace=True)
    
    raw['P_diff']=raw['Price'].diff(1)
    raw['P_diff'].fillna(0,inplace=True)
    raw['Year_a_go'] = raw['Price'].shift(365)
    raw['Y_diff'] = raw['Price']-raw['Year_a_go']
    raw['P_sum'] = raw['Price']+raw['P_diff']

    raw['month'] =(raw['month'] + (raw.year - raw.year.min()) * 12)
    mapd = raw.groupby('month')['Price'].mean()
    mapd = pd.DataFrame(mapd,index=mapd.index)  
    mapd.reset_index(drop=False,inplace=True)
    mapd.columns=['month','Mapd']
    raw = pd.merge(raw,mapd,how='left',left_on='month',right_on='month')
    raw['R_p'] = raw['Price']-raw['Mapd']
    
    raw.drop(['Mapd'],axis=1,inplace=True)
    
    return raw

# %% [markdown]
# # Data Partitioning

# %%
# Raw dataset selection
raw=raw[raw.index <= USEDATE]

# Train,Test split
test=raw[raw.index >= BASEDATE]
train=raw[raw.index < BASEDATE]
raw_idx = raw.index
train_idx = train.index

# %% [markdown]
# # MLP with FE

# %%
VERBOSE = 2
pred=[]

with tf.device("/device:CPU:0"):
    
    for day_num in tqdm(SELECTED):
        
        train_all = []
        train_all = raw.iloc[:,:1]

        
        # Price에 Outlier Treatment 적용 ---------------------#

        winsor_list = []
        winsor_list.append(WINSOR)
        winsor_list.append(100 - WINSOR)

        winsors = np.percentile(train_all['Price'][train_all.index < BASEDATE], winsor_list)
        winsor_min = winsors[0]
        winsor_max = winsors[1]

        train_all['Price'][train_all.index < BASEDATE] = np.where(train_all['Price'][train_all.index < BASEDATE] < winsor_min, winsor_min, train_all['Price'][train_all.index < BASEDATE])
        train_all['Price'][train_all.index < BASEDATE] = np.where(train_all['Price'][train_all.index < BASEDATE] > winsor_max, winsor_max, train_all['Price'][train_all.index < BASEDATE])

        #-----------------------------------------------------#
        
        V = pd.DataFrame(columns=['V'],index=raw.index)
        for i in range(day_num, IRANGE + day_num):
            train_all[f'Price_{i}lag'] = train_all['Price'].shift(i)
        
        raw_all = train_all.iloc[day_num:]
        raw_seed = raw_all.iloc[:,1:2]
        raw_seed.columns=['Price']
        raw_seed = feature_engineering(raw_seed)
        seed = raw_seed.iloc[:,1:]
        seed.index = raw_idx[day_num:]
        
        if VARS == 2:  # 거래량을 사용할 경우에만 처리
            V['Volume'] = raw['Volume'].shift(day_num)
            V['Volume'].iloc[day_num:]
            raw_final = pd.concat([raw_all,seed,V['Volume']],axis=1)
        else:
            raw_final = raw_all
        
        raw_final = raw_final.dropna(axis=0)  # NaN 결측치가 있는 경우, 학습대상에서 제외

        train_old = raw_final[raw_final.index < BASEDATE]
        test_new = raw_final[raw_final.index >= BASEDATE]

        
        # 검증기간 데이터 FRAC 추가  ---------------------#
        
        train_new = train_old.append(test_new.sample(frac=FRAC))
        
        y_train_raw = train_new['Price']
        x_train_raw = train_new.drop(['Price'],axis=1)        

        #-----------------------------------------------------#
        
        
        # Min-Max Normalization 적용
        scaler_X_tr = preprocessing.MinMaxScaler(feature_range=(0,1))
        X_train = scaler_X_tr.fit_transform(x_train_raw)

        
        
        # Validation 데이터을 학습에 사용할 경우에 대한 처리        
        
        if SPLIT == 0:
            x_train = X_train
            y_train = y_train_raw
        else:
            x_train = X_train[:-SPLIT]
            y_train = y_train_raw[:-SPLIT]
            x_valid = X_train[-SPLIT:]
            y_valid = y_train_raw[-SPLIT:]
            
        # MLP Training

        model = Sequential()
        model.add(Dense(X_train.shape[1], input_shape=(X_train.shape[1],), activation='elu'))
        model.add(Dropout(DROPOUT))
        model.add(Dense(2*(X_train.shape[1]), activation='elu'))
        model.add(Dropout(DROPOUT))
        model.add(Dense(1,activation='linear'))
        model.compile(optimizer='adam', loss='mean_squared_error')
        model.summary()
        
        
        if SPLIT == 0:
            ES = EarlyStopping(monitor='loss', mode='min', patience=PATIENCE, restore_best_weights=True)        
            model_fit = model.fit(x_train, y_train, 
                                  batch_size=BATCH, epochs=EPOCH, callbacks=ES,
                                  verbose=VERBOSE)
        else:
            ES = EarlyStopping(monitor='val_loss', mode='min', patience=PATIENCE, restore_best_weights=True)        
            model_fit = model.fit(x_train, y_train, validation_data=(x_valid, y_valid), 
                                  batch_size=BATCH, epochs=EPOCH, callbacks=ES,
                                  verbose=VERBOSE)
        
        model.save(f'{PDCODE}_{SMCODE}V{VARS}_{MDCODE}wFE_{day_num}')
    
        plt.plot(pd.DataFrame(model_fit.history))
        plt.grid(True)
        plt.show()

        # 학습한 결과의 예측모델 출력  ---------------------#
        
        y_train_real = train_old['Price']
        x_train_pred = scaler_X_tr.fit_transform(train_old.drop(['Price'],axis=1)) 
        y_train_pred = model.predict(x_train_pred)        
        
        print(f'{PDNAME} / {MDCODE}+FE / Model{day_num} Training Result\n')

        plot_data = pd.concat([pd.DataFrame(y_train_real.values, columns=['actual']), pd.DataFrame(y_train_pred, columns=['pred'])], axis=1)
        date_label = pd.date_range(start=train_old.index[0], end=train_old.index[-1], freq='D')

        fig, ax = plt.subplots(figsize=(15,6))

        ax.plot(date_label, plot_data)

        plt.title(PDNAME + ' / ' + MDCODE + '+FE / Model ' + str(day_num) + ' Training Result', fontsize=14)
        plt.xlabel('Date', fontsize=10)
        plt.ylabel('Price', fontsize=10)

        dateFmt = mdates.DateFormatter('%y-%m-%d')
        ax.xaxis.set_major_formatter(dateFmt)

        plt.show()
        plt.clf()        
        
        #-----------------------------------------------------#
        
        x_test = test_new.iloc[:,1:]
        y_test = test_new['Price']
        X_test= scaler_X_tr.transform(x_test)
        y_test_pred = model.predict(X_test)
        
        pred.append(y_test_pred)
# Out:
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 395)               156420
#
#  dropout (Dropout)           (None, 395)               0
#
#  dense_1 (Dense)             (None, 790)               312840
#
#  dropout_1 (Dropout)         (None, 790)               0
#
#  dense_2 (Dense)             (None, 1)                 791
#
# =================================================================
# Total params: 470,051
# Trainable params: 470,051
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 78/78 - 1s - loss: 206782.2344 - val_loss: 131729.5781 - 940ms/epoch - 12ms/step
# Epoch 2/200
# 78/78 - 0s - loss: 42047.6484 - val_loss: 114398.9922 - 388ms/epoch - 5ms/step
# Epoch 3/200
# 78/78 - 0s - loss: 27544.2793 - val_loss: 87405.4375 - 370ms/epoch - 5ms/step
# Epoch 4/200
# 78/78 - 0s - loss: 21208.6406 - val_loss: 81643.1406 - 378ms/epoch - 5ms/step
# Epoch 5/200
# 78/78 - 0s - loss: 18816.1230 - val_loss: 83099.5781 - 370ms/epoch - 5ms/step
# Epoch 6/200
# 78/78 - 0s - loss: 17725.0312 - val_loss: 80099.1562 - 336ms/epoch - 4ms/step
# Epoch 7/200
# 78/78 - 0s - loss: 17164.3457 - val_loss: 81012.8750 - 367ms/epoch - 5ms/step
# Epoch 8/200
# 78/78 - 0s - loss: 16214.9912 - val_loss: 78857.3125 - 353ms/epoch - 5ms/step
# Epoch 9/200
# 78/78 - 0s - loss: 15757.6523 - val_loss: 73336.2969 - 366ms/epoch - 5ms/step
# Epoch 10/200
# 78/78 - 0s - loss: 14604.3125 - val_loss: 67662.8906 - 374ms/epoch - 5ms/step
# Epoch 11/200
# 78/78 - 0s - loss: 13627.5059 - val_loss: 63479.8438 - 338ms/epoch - 4ms/step
# Epoch 12/200
# 78/78 - 0s - loss: 13196.4160 - val_loss: 53322.6133 - 353ms/epoch - 5ms/step
# Epoch 13/200
# 78/78 - 0s - loss: 12531.5723 - val_loss: 60600.8281 - 386ms/epoch - 5ms/step
# Epoch 14/200
# 78/78 - 0s - loss: 12150.6074 - val_loss: 51303.8086 - 370ms/epoch - 5ms/step
# Epoch 15/200
# 78/78 - 0s - loss: 11352.7021 - val_loss: 46090.8750 - 357ms/epoch - 5ms/step
# Epoch 16/200
# 78/78 - 0s - loss: 10712.6963 - val_loss: 45296.9102 - 352ms/epoch - 5ms/step
# Epoch 17/200
# 78/78 - 0s - loss: 10148.4424 - val_loss: 40926.6250 - 353ms/epoch - 5ms/step
# Epoch 18/200
# 78/78 - 0s - loss: 9903.8936 - val_loss: 46455.1445 - 376ms/epoch - 5ms/step
# Epoch 19/200
# 78/78 - 0s - loss: 9600.8525 - val_loss: 50931.3828 - 365ms/epoch - 5ms/step
# Epoch 20/200
# 78/78 - 0s - loss: 9917.9873 - val_loss: 50658.4766 - 330ms/epoch - 4ms/step
# Epoch 21/200
# 78/78 - 0s - loss: 8888.6514 - val_loss: 50109.1914 - 432ms/epoch - 6ms/step
# Epoch 22/200
# 78/78 - 0s - loss: 8441.5293 - val_loss: 53117.6953 - 324ms/epoch - 4ms/step
# Epoch 23/200
# 78/78 - 0s - loss: 8452.6406 - val_loss: 54290.6289 - 333ms/epoch - 4ms/step
# Epoch 24/200
# 78/78 - 0s - loss: 7752.2065 - val_loss: 55303.5820 - 365ms/epoch - 5ms/step
# Epoch 25/200
# 78/78 - 0s - loss: 7277.6294 - val_loss: 48142.7227 - 384ms/epoch - 5ms/step
# Epoch 26/200
# 78/78 - 0s - loss: 7039.7979 - val_loss: 45926.7891 - 368ms/epoch - 5ms/step
# Epoch 27/200
# 78/78 - 0s - loss: 6743.7129 - val_loss: 37406.7305 - 365ms/epoch - 5ms/step
# Epoch 28/200
# 78/78 - 0s - loss: 6350.9258 - val_loss: 58025.9102 - 333ms/epoch - 4ms/step
# Epoch 29/200
# 78/78 - 0s - loss: 6489.8501 - val_loss: 41025.5273 - 390ms/epoch - 5ms/step
# Epoch 30/200
# 78/78 - 0s - loss: 5756.7700 - val_loss: 45165.6523 - 332ms/epoch - 4ms/step
# Epoch 31/200
# 78/78 - 0s - loss: 5864.4512 - val_loss: 40346.3516 - 370ms/epoch - 5ms/step
# Epoch 32/200
# 78/78 - 0s - loss: 5602.6479 - val_loss: 48826.8906 - 365ms/epoch - 5ms/step
# Epoch 33/200
# 78/78 - 0s - loss: 5352.9463 - val_loss: 40865.7422 - 384ms/epoch - 5ms/step
# Epoch 34/200
# 78/78 - 0s - loss: 5372.8975 - val_loss: 41384.9961 - 340ms/epoch - 4ms/step
# Epoch 35/200
# 78/78 - 0s - loss: 5413.0508 - val_loss: 38406.3867 - 340ms/epoch - 4ms/step
# Epoch 36/200
# 78/78 - 0s - loss: 5242.4390 - val_loss: 35736.4297 - 346ms/epoch - 4ms/step
# Epoch 37/200
# 78/78 - 0s - loss: 4875.8975 - val_loss: 45936.2578 - 353ms/epoch - 5ms/step
# Epoch 38/200
# 78/78 - 0s - loss: 5066.9790 - val_loss: 39736.6367 - 357ms/epoch - 5ms/step
# Epoch 39/200
# 78/78 - 0s - loss: 4849.2168 - val_loss: 47218.8945 - 362ms/epoch - 5ms/step
# Epoch 40/200
# 78/78 - 0s - loss: 4439.4414 - val_loss: 42568.2305 - 373ms/epoch - 5ms/step
# Epoch 41/200
# 78/78 - 0s - loss: 4716.5342 - val_loss: 47120.3867 - 362ms/epoch - 5ms/step
# Epoch 42/200
# 78/78 - 0s - loss: 4576.8262 - val_loss: 42043.1953 - 348ms/epoch - 4ms/step
# Epoch 43/200
# 78/78 - 0s - loss: 4760.8550 - val_loss: 41262.3555 - 367ms/epoch - 5ms/step
# Epoch 44/200
# 78/78 - 0s - loss: 4641.9399 - val_loss: 42903.3750 - 376ms/epoch - 5ms/step
# Epoch 45/200
# 78/78 - 0s - loss: 4938.9658 - val_loss: 38288.8672 - 344ms/epoch - 4ms/step
# Epoch 46/200
# 78/78 - 0s - loss: 4687.4502 - val_loss: 44425.5273 - 361ms/epoch - 5ms/step
# INFO:tensorflow:Assets written to: ONI_S1M2V2_MLPwFE_30\assets
# 78/78 [==============================] - 0s 2ms/step
# Onion / MLP+FE / Model30 Training Result
# 7/7 [==============================] - 0s 2ms/step
#  20%|████████████████▊                                                                   | 1/5 [00:19<01:16, 19.16s/it]
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 395)               156420
#
#  dropout_2 (Dropout)         (None, 395)               0
#
#  dense_4 (Dense)             (None, 790)               312840
#
#  dropout_3 (Dropout)         (None, 790)               0
#
#  dense_5 (Dense)             (None, 1)                 791
#
# =================================================================
# Total params: 470,051
# Trainable params: 470,051
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 76/76 - 1s - loss: 244579.0156 - val_loss: 154067.5938 - 734ms/epoch - 10ms/step
# Epoch 2/200
# 76/76 - 0s - loss: 73623.8203 - val_loss: 171211.3906 - 375ms/epoch - 5ms/step
# Epoch 3/200
# 76/76 - 0s - loss: 46403.7148 - val_loss: 162636.5938 - 341ms/epoch - 4ms/step
# Epoch 4/200
# 76/76 - 0s - loss: 40588.6875 - val_loss: 186028.0312 - 347ms/epoch - 5ms/step
# Epoch 5/200
# 76/76 - 0s - loss: 37107.1016 - val_loss: 200090.3594 - 358ms/epoch - 5ms/step
# Epoch 6/200
# 76/76 - 0s - loss: 34589.1328 - val_loss: 198235.8438 - 356ms/epoch - 5ms/step
# Epoch 7/200
# 76/76 - 0s - loss: 33127.0938 - val_loss: 212996.7656 - 347ms/epoch - 5ms/step
# Epoch 8/200
# 76/76 - 0s - loss: 29753.6953 - val_loss: 183337.7500 - 361ms/epoch - 5ms/step
# Epoch 9/200
# 76/76 - 0s - loss: 26505.0195 - val_loss: 180762.5156 - 338ms/epoch - 4ms/step
# Epoch 10/200
# 76/76 - 0s - loss: 22611.1543 - val_loss: 184426.8906 - 349ms/epoch - 5ms/step
# Epoch 11/200
# 76/76 - 0s - loss: 19989.0527 - val_loss: 187538.0156 - 371ms/epoch - 5ms/step
# INFO:tensorflow:Assets written to: ONI_S1M2V2_MLPwFE_90\assets
# 76/76 [==============================] - 0s 2ms/step
# Onion / MLP+FE / Model90 Training Result
# 7/7 [==============================] - 0s 2ms/step
#  40%|█████████████████████████████████▌                                                  | 2/5 [00:24<00:33, 11.29s/it]
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 395)               156420
#
#  dropout_4 (Dropout)         (None, 395)               0
#
#  dense_7 (Dense)             (None, 790)               312840
#
#  dropout_5 (Dropout)         (None, 790)               0
#
#  dense_8 (Dense)             (None, 1)                 791
#
# =================================================================
# Total params: 470,051
# Trainable params: 470,051
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 73/73 - 1s - loss: 273073.6562 - val_loss: 134142.1094 - 748ms/epoch - 10ms/step
# Epoch 2/200
# 73/73 - 0s - loss: 95882.6016 - val_loss: 89426.5781 - 351ms/epoch - 5ms/step
# Epoch 3/200
# 73/73 - 0s - loss: 55203.9961 - val_loss: 115141.0156 - 351ms/epoch - 5ms/step
# Epoch 4/200
# 73/73 - 0s - loss: 45822.3867 - val_loss: 133484.2031 - 370ms/epoch - 5ms/step
# Epoch 5/200
# 73/73 - 0s - loss: 41535.3398 - val_loss: 147090.4375 - 338ms/epoch - 5ms/step
# Epoch 6/200
# 73/73 - 0s - loss: 38943.9375 - val_loss: 173750.3125 - 363ms/epoch - 5ms/step
# Epoch 7/200
# 73/73 - 0s - loss: 33103.9688 - val_loss: 184413.2188 - 366ms/epoch - 5ms/step
# Epoch 8/200
# 73/73 - 0s - loss: 28211.4121 - val_loss: 185875.8594 - 358ms/epoch - 5ms/step
# Epoch 9/200
# 73/73 - 0s - loss: 22148.3594 - val_loss: 195395.3906 - 372ms/epoch - 5ms/step
# Epoch 10/200
# 73/73 - 0s - loss: 18157.4980 - val_loss: 196499.3281 - 304ms/epoch - 4ms/step
# Epoch 11/200
# 73/73 - 0s - loss: 15291.5723 - val_loss: 204377.1094 - 365ms/epoch - 5ms/step
# Epoch 12/200
# 73/73 - 0s - loss: 12496.7275 - val_loss: 243189.4062 - 352ms/epoch - 5ms/step
# INFO:tensorflow:Assets written to: ONI_S1M2V2_MLPwFE_180\assets
# 73/73 [==============================] - 0s 2ms/step
# Onion / MLP+FE / Model180 Training Result
# 7/7 [==============================] - 0s 2ms/step
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [00:31<00:17,  8.93s/it]
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 395)               156420
#
#  dropout_6 (Dropout)         (None, 395)               0
#
#  dense_10 (Dense)            (None, 790)               312840
#
#  dropout_7 (Dropout)         (None, 790)               0
#
#  dense_11 (Dense)            (None, 1)                 791
#
# =================================================================
# Total params: 470,051
# Trainable params: 470,051
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 70/70 - 1s - loss: 261732.4531 - val_loss: 106735.6484 - 738ms/epoch - 11ms/step
# Epoch 2/200
# 70/70 - 0s - loss: 89348.3672 - val_loss: 74943.4609 - 342ms/epoch - 5ms/step
# Epoch 3/200
# 70/70 - 0s - loss: 53285.5820 - val_loss: 91238.8359 - 350ms/epoch - 5ms/step
# Epoch 4/200
# 70/70 - 0s - loss: 44334.1055 - val_loss: 105982.8828 - 349ms/epoch - 5ms/step
# Epoch 5/200
# 70/70 - 0s - loss: 38690.9531 - val_loss: 112644.6562 - 332ms/epoch - 5ms/step
# Epoch 6/200
# 70/70 - 0s - loss: 34527.1914 - val_loss: 105545.0312 - 339ms/epoch - 5ms/step
# Epoch 7/200
# 70/70 - 0s - loss: 30440.8672 - val_loss: 127198.0078 - 350ms/epoch - 5ms/step
# Epoch 8/200
# 70/70 - 0s - loss: 26655.1895 - val_loss: 119738.2656 - 299ms/epoch - 4ms/step
# Epoch 9/200
# 70/70 - 0s - loss: 23877.5039 - val_loss: 128973.9062 - 309ms/epoch - 4ms/step
# Epoch 10/200
# 70/70 - 0s - loss: 20827.7656 - val_loss: 116372.7812 - 339ms/epoch - 5ms/step
# Epoch 11/200
# 70/70 - 0s - loss: 18669.1543 - val_loss: 136356.5938 - 324ms/epoch - 5ms/step
# Epoch 12/200
# 70/70 - 0s - loss: 16984.7363 - val_loss: 122612.1016 - 332ms/epoch - 5ms/step
# INFO:tensorflow:Assets written to: ONI_S1M2V2_MLPwFE_270\assets
# 70/70 [==============================] - 0s 2ms/step
# Onion / MLP+FE / Model270 Training Result
# 7/7 [==============================] - 0s 3ms/step
#  80%|███████████████████████████████████████████████████████████████████▏                | 4/5 [00:37<00:07,  7.79s/it]
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 395)               156420
#
#  dropout_8 (Dropout)         (None, 395)               0
#
#  dense_13 (Dense)            (None, 790)               312840
#
#  dropout_9 (Dropout)         (None, 790)               0
#
#  dense_14 (Dense)            (None, 1)                 791
#
# =================================================================
# Total params: 470,051
# Trainable params: 470,051
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 67/67 - 1s - loss: 251561.2812 - val_loss: 186249.0312 - 744ms/epoch - 11ms/step
# Epoch 2/200
# 67/67 - 0s - loss: 89085.7656 - val_loss: 173853.0312 - 339ms/epoch - 5ms/step
# Epoch 3/200
# 67/67 - 0s - loss: 53776.7852 - val_loss: 114816.8203 - 337ms/epoch - 5ms/step
# Epoch 4/200
# 67/67 - 0s - loss: 44703.1953 - val_loss: 102135.6875 - 342ms/epoch - 5ms/step
# Epoch 5/200
# 67/67 - 0s - loss: 38238.6523 - val_loss: 95381.4297 - 310ms/epoch - 5ms/step
# Epoch 6/200
# 67/67 - 0s - loss: 31590.4199 - val_loss: 86491.6406 - 317ms/epoch - 5ms/step
# Epoch 7/200
# 67/67 - 0s - loss: 26569.9648 - val_loss: 64575.9336 - 297ms/epoch - 4ms/step
# Epoch 8/200
# 67/67 - 0s - loss: 23546.7188 - val_loss: 64246.1055 - 345ms/epoch - 5ms/step
# Epoch 9/200
# 67/67 - 0s - loss: 18533.5840 - val_loss: 42661.8047 - 307ms/epoch - 5ms/step
# Epoch 10/200
# 67/67 - 0s - loss: 14353.2559 - val_loss: 41577.5625 - 341ms/epoch - 5ms/step
# Epoch 11/200
# 67/67 - 0s - loss: 11371.8037 - val_loss: 34151.5977 - 331ms/epoch - 5ms/step
# Epoch 12/200
# 67/67 - 0s - loss: 11130.7891 - val_loss: 28228.8242 - 321ms/epoch - 5ms/step
# Epoch 13/200
# 67/67 - 0s - loss: 8407.3555 - val_loss: 30158.8340 - 317ms/epoch - 5ms/step
# Epoch 14/200
# 67/67 - 0s - loss: 7529.4336 - val_loss: 31509.6406 - 321ms/epoch - 5ms/step
# Epoch 15/200
# 67/67 - 0s - loss: 6782.6274 - val_loss: 27227.9336 - 326ms/epoch - 5ms/step
# Epoch 16/200
# 67/67 - 0s - loss: 6816.0098 - val_loss: 23510.0215 - 320ms/epoch - 5ms/step
# Epoch 17/200
# 67/67 - 0s - loss: 5756.0869 - val_loss: 26294.8516 - 361ms/epoch - 5ms/step
# Epoch 18/200
# 67/67 - 0s - loss: 6189.8691 - val_loss: 35866.3633 - 284ms/epoch - 4ms/step
# Epoch 19/200
# 67/67 - 0s - loss: 6557.5776 - val_loss: 32345.7383 - 311ms/epoch - 5ms/step
# Epoch 20/200
# 67/67 - 0s - loss: 5857.6104 - val_loss: 24308.6992 - 315ms/epoch - 5ms/step
# Epoch 21/200
# 67/67 - 0s - loss: 5605.2651 - val_loss: 36776.7422 - 312ms/epoch - 5ms/step
# Epoch 22/200
# 67/67 - 0s - loss: 5066.2627 - val_loss: 32083.1426 - 313ms/epoch - 5ms/step
# Epoch 23/200
# 67/67 - 0s - loss: 5682.6128 - val_loss: 28848.7734 - 353ms/epoch - 5ms/step
# Epoch 24/200
# 67/67 - 0s - loss: 4998.3247 - val_loss: 32541.1211 - 286ms/epoch - 4ms/step
# Epoch 25/200
# 67/67 - 0s - loss: 4805.7432 - val_loss: 23713.1230 - 304ms/epoch - 5ms/step
# Epoch 26/200
# 67/67 - 0s - loss: 5045.5938 - val_loss: 24831.9004 - 321ms/epoch - 5ms/step
# INFO:tensorflow:Assets written to: ONI_S1M2V2_MLPwFE_365\assets
# 67/67 [==============================] - 0s 2ms/step
# Onion / MLP+FE / Model365 Training Result
# 7/7 [==============================] - 0s 2ms/step
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:47<00:00,  9.48s/it]

# %% [markdown]
# # MLP with FE / Visualization

# %%
for i in range(0, NSEL):
    
    print(f'Model{SELECTED[i]} Results\n')

    plot_data = pd.DataFrame([y_test.values, pred[i]]).T
    date_label = pd.date_range(start=x_test.index[0], end=x_test.index[-1], freq='D')
    
    fig, ax = plt.subplots(figsize=(15,6))
        
    plot_data.columns = ['actual','pred']
    ax.plot(date_label, plot_data)
    
    plt.title(PDNAME + ' / ' + MDCODE + '+FE / Model ' + str(SELECTED[i]) + ' Test Result', fontsize=14)
    plt.xlabel('Date', fontsize=10)
    plt.ylabel('Price', fontsize=10)
    
    dateFmt = mdates.DateFormatter('%y-%m-%d')
    ax.xaxis.set_major_formatter(dateFmt)
    
    plt.show()
    plt.clf()
    
    MAPE = mean_absolute_percentage_error(y_test.values.flatten(), pred[i])*100
    print(f'MAPE={MAPE}')

    RMSE = np.sqrt(mean_squared_error(y_test.values.flatten(), pred[i]))
    print(f'RMSE={RMSE}\n\n\n')
# Out:
# Model30 Results
# MAPE=35.70764623005896
# RMSE=270.4989991514053
#
#
#
# Model90 Results
# MAPE=59.501061274703204
# RMSE=402.57513370230237
#
#
#
# Model180 Results
# MAPE=50.708601319015756
# RMSE=299.51817116742313
#
#
#
# Model270 Results
# MAPE=46.91196177423584
# RMSE=274.64835504869467
#
#
#
# Model365 Results
# MAPE=22.000178113270827
# RMSE=164.99854593295785

# %% [markdown]
# # MLP without FE

# %%
VERBOSE = 2
pred=[]

with tf.device("/device:CPU:0"):  

    for day_num in tqdm(SELECTED):
        
        train_all = []
        train_all = raw.iloc[:,:2]

        # Price에 Outlier Treatment 적용 ---------------------#

        winsor_list = []
        winsor_list.append(WINSOR)
        winsor_list.append(100 - WINSOR)

        winsors = np.percentile(train_all['Price'][train_all.index < BASEDATE], winsor_list)
        winsor_min = winsors[0]
        winsor_max = winsors[1]

        train_all['Price'][train_all.index < BASEDATE] = np.where(train_all['Price'][train_all.index < BASEDATE] < winsor_min, winsor_min, train_all['Price'][train_all.index < BASEDATE])
        train_all['Price'][train_all.index < BASEDATE] = np.where(train_all['Price'][train_all.index < BASEDATE] > winsor_max, winsor_max, train_all['Price'][train_all.index < BASEDATE])

        #-----------------------------------------------------#
        
        
        for i in range(day_num, 365 + day_num):
            train_all[f'Price_{i}lag'] = train_all['Price'].shift(i)

        if VARS == 2:  # 거래량을 사용할 경우에만 처리    
            train_all['Volume'] = train_all['Volume'].shift(day_num)
        
        train_all = train_all.dropna(axis=0)  # NaN 결측치가 있는 경우, 학습대상에서 제외
        
        
        train_old = train_all[train_all.index < BASEDATE]
        test_new = train_all[train_all.index >= BASEDATE]   
        
        
        # 검증기간 데이터 FRAC 추가  ---------------------#
        
        train_new = train_old.append(test_new.sample(frac=FRAC))
        
        y_train_raw = train_new['Price']
        x_train_raw = train_new.drop(['Price'],axis=1)        

        #-----------------------------------------------------#
        
        
        # Min-Max Normalization 적용
        scaler_X_tr = preprocessing.MinMaxScaler(feature_range=(0,1))
        X_train = scaler_X_tr.fit_transform(x_train_raw)
        

        # Validation 데이터을 학습에 사용할 경우에 대한 처리        
        
        if SPLIT == 0:
            x_train = X_train
            y_train = y_train_raw
        else:
            x_train = X_train[:-SPLIT]
            y_train = y_train_raw[:-SPLIT]
            x_valid = X_train[-SPLIT:]
            y_valid = y_train_raw[-SPLIT:]


        # MLP Training

        model = Sequential()
        model.add(Dense(X_train.shape[1], input_shape=(X_train.shape[1],), activation='elu'))
        model.add(Dropout(DROPOUT))
        model.add(Dense(2*(X_train.shape[1]), activation='elu'))
        model.add(Dropout(DROPOUT))
        model.add(Dense(1,activation='linear'))
        model.compile(optimizer='adam', loss='mean_squared_error')
        model.summary()
        

        
        if SPLIT == 0:
            ES = EarlyStopping(monitor='loss', mode='min', patience=PATIENCE, restore_best_weights=True)        
            model_fit = model.fit(x_train, y_train, 
                                  batch_size=BATCH, epochs=EPOCH, callbacks=ES,
                                  verbose=VERBOSE)
        else:
            ES = EarlyStopping(monitor='val_loss', mode='min', patience=PATIENCE, restore_best_weights=True)        
            model_fit = model.fit(x_train, y_train, validation_data=(x_valid, y_valid), 
                                  batch_size=BATCH, epochs=EPOCH, callbacks=ES,
                                  verbose=VERBOSE)
        
        model.save(f'{PDCODE}_{SMCODE}V{VARS}_{MDCODE}woFE_{day_num}')
    
        plt.plot(pd.DataFrame(model_fit.history))
        plt.grid(True)
        plt.show()

        # 학습한 결과의 예측모델 출력  ---------------------#
        
        y_train_real = train_old['Price']
        x_train_pred = scaler_X_tr.fit_transform(train_old.drop(['Price'],axis=1)) 
        y_train_pred = model.predict(x_train_pred)        
        
        print(f'{PDNAME} / {MDCODE} / Model{day_num} Training Result\n')

        plot_data = pd.concat([pd.DataFrame(y_train_real.values, columns=['actual']), pd.DataFrame(y_train_pred, columns=['pred'])], axis=1)
        date_label = pd.date_range(start=train_old.index[0], end=train_old.index[-1], freq='D')

        fig, ax = plt.subplots(figsize=(15,6))

        ax.plot(date_label, plot_data)

        plt.title(PDNAME + ' / ' + MDCODE + ' / Model ' + str(day_num) + ' Training Result', fontsize=14)
        plt.xlabel('Date', fontsize=10)
        plt.ylabel('Price', fontsize=10)

        dateFmt = mdates.DateFormatter('%y-%m-%d')
        ax.xaxis.set_major_formatter(dateFmt)

        plt.show()
        plt.clf()        
        
        #-----------------------------------------------------#
        
        x_test = test_new.iloc[:,1:]
        y_test = test_new['Price']
        X_test= scaler_X_tr.transform(x_test)
        y_test_pred = model.predict(X_test)
        
        pred.append(y_test_pred)
# Out:
#   0%|                                                                                            | 0/5 [00:00<?, ?it/s]
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 366)               134322
#
#  dropout_10 (Dropout)        (None, 366)               0
#
#  dense_16 (Dense)            (None, 732)               268644
#
#  dropout_11 (Dropout)        (None, 732)               0
#
#  dense_17 (Dense)            (None, 1)                 733
#
# =================================================================
# Total params: 403,699
# Trainable params: 403,699
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 78/78 - 1s - loss: 228573.2812 - val_loss: 140555.9375 - 746ms/epoch - 10ms/step
# Epoch 2/200
# 78/78 - 0s - loss: 53404.7109 - val_loss: 131525.1562 - 350ms/epoch - 4ms/step
# Epoch 3/200
# 78/78 - 0s - loss: 35901.7227 - val_loss: 95317.2344 - 364ms/epoch - 5ms/step
# Epoch 4/200
# 78/78 - 0s - loss: 28726.4082 - val_loss: 68420.2500 - 357ms/epoch - 5ms/step
# Epoch 5/200
# 78/78 - 0s - loss: 24207.3652 - val_loss: 57889.0938 - 344ms/epoch - 4ms/step
# Epoch 6/200
# 78/78 - 0s - loss: 21356.5215 - val_loss: 56548.8008 - 341ms/epoch - 4ms/step
# Epoch 7/200
# 78/78 - 0s - loss: 19713.5801 - val_loss: 54293.4102 - 364ms/epoch - 5ms/step
# Epoch 8/200
# 78/78 - 0s - loss: 18986.8262 - val_loss: 57184.1602 - 353ms/epoch - 5ms/step
# Epoch 9/200
# 78/78 - 0s - loss: 18397.0605 - val_loss: 54409.7891 - 333ms/epoch - 4ms/step
# Epoch 10/200
# 78/78 - 0s - loss: 17804.3867 - val_loss: 53886.4922 - 338ms/epoch - 4ms/step
# Epoch 11/200
# 78/78 - 0s - loss: 17407.7109 - val_loss: 56911.4609 - 324ms/epoch - 4ms/step
# Epoch 12/200
# 78/78 - 0s - loss: 17208.4688 - val_loss: 52133.7695 - 330ms/epoch - 4ms/step
# Epoch 13/200
# 78/78 - 0s - loss: 16688.0957 - val_loss: 50772.0938 - 328ms/epoch - 4ms/step
# Epoch 14/200
# 78/78 - 0s - loss: 15808.5967 - val_loss: 48050.0703 - 312ms/epoch - 4ms/step
# Epoch 15/200
# 78/78 - 0s - loss: 15904.5068 - val_loss: 45773.5469 - 324ms/epoch - 4ms/step
# Epoch 16/200
# 78/78 - 0s - loss: 15315.5146 - val_loss: 44342.3008 - 337ms/epoch - 4ms/step
# Epoch 17/200
# 78/78 - 0s - loss: 13796.1055 - val_loss: 41182.4844 - 334ms/epoch - 4ms/step
# Epoch 18/200
# 78/78 - 0s - loss: 12860.5176 - val_loss: 37339.3125 - 346ms/epoch - 4ms/step
# Epoch 19/200
# 78/78 - 0s - loss: 12021.2168 - val_loss: 38942.8555 - 351ms/epoch - 4ms/step
# Epoch 20/200
# 78/78 - 0s - loss: 11353.2129 - val_loss: 42841.7227 - 361ms/epoch - 5ms/step
# Epoch 21/200
# 78/78 - 0s - loss: 10737.5947 - val_loss: 41099.3672 - 311ms/epoch - 4ms/step
# Epoch 22/200
# 78/78 - 0s - loss: 10238.4688 - val_loss: 37997.6172 - 330ms/epoch - 4ms/step
# Epoch 23/200
# 78/78 - 0s - loss: 9940.6621 - val_loss: 40700.3086 - 316ms/epoch - 4ms/step
# Epoch 24/200
# 78/78 - 0s - loss: 9172.4473 - val_loss: 39771.4180 - 327ms/epoch - 4ms/step
# Epoch 25/200
# 78/78 - 0s - loss: 9067.2207 - val_loss: 38210.8750 - 350ms/epoch - 4ms/step
# Epoch 26/200
# 78/78 - 0s - loss: 8468.3477 - val_loss: 40575.7695 - 336ms/epoch - 4ms/step
# Epoch 27/200
# 78/78 - 0s - loss: 8528.5352 - val_loss: 37704.6328 - 351ms/epoch - 5ms/step
# Epoch 28/200
# 78/78 - 0s - loss: 7984.8115 - val_loss: 38610.3945 - 308ms/epoch - 4ms/step
# INFO:tensorflow:Assets written to: ONI_S1M2V2_MLPwoFE_30\assets
# 78/78 [==============================] - 0s 2ms/step
# Onion / MLP / Model30 Training Result
# 7/7 [==============================] - 0s 2ms/step
#  20%|████████████████▊                                                                   | 1/5 [00:11<00:45, 11.31s/it]
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 366)               134322
#
#  dropout_12 (Dropout)        (None, 366)               0
#
#  dense_19 (Dense)            (None, 732)               268644
#
#  dropout_13 (Dropout)        (None, 732)               0
#
#  dense_20 (Dense)            (None, 1)                 733
#
# =================================================================
# Total params: 403,699
# Trainable params: 403,699
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 76/76 - 1s - loss: 269071.7500 - val_loss: 163061.2500 - 908ms/epoch - 12ms/step
# Epoch 2/200
# 76/76 - 0s - loss: 88016.8516 - val_loss: 166675.8438 - 375ms/epoch - 5ms/step
# Epoch 3/200
# 76/76 - 0s - loss: 57723.4688 - val_loss: 159923.1094 - 338ms/epoch - 4ms/step
# Epoch 4/200
# 76/76 - 0s - loss: 49325.8086 - val_loss: 150581.8438 - 335ms/epoch - 4ms/step
# Epoch 5/200
# 76/76 - 0s - loss: 44471.5977 - val_loss: 161548.9219 - 342ms/epoch - 4ms/step
# Epoch 6/200
# 76/76 - 0s - loss: 41791.1758 - val_loss: 156005.8594 - 346ms/epoch - 5ms/step
# Epoch 7/200
# 76/76 - 0s - loss: 39448.2070 - val_loss: 188166.1719 - 342ms/epoch - 5ms/step
# Epoch 8/200
# 76/76 - 0s - loss: 37727.8281 - val_loss: 177666.4375 - 367ms/epoch - 5ms/step
# Epoch 9/200
# 76/76 - 0s - loss: 36900.2773 - val_loss: 192465.0625 - 367ms/epoch - 5ms/step
# Epoch 10/200
# 76/76 - 0s - loss: 35354.2344 - val_loss: 194451.0156 - 345ms/epoch - 5ms/step
# Epoch 11/200
# 76/76 - 0s - loss: 33631.0703 - val_loss: 204682.9688 - 385ms/epoch - 5ms/step
# Epoch 12/200
# 76/76 - 0s - loss: 32299.0547 - val_loss: 202973.1406 - 357ms/epoch - 5ms/step
# Epoch 13/200
# 76/76 - 0s - loss: 29989.3340 - val_loss: 225990.6875 - 338ms/epoch - 4ms/step
# Epoch 14/200
# 76/76 - 0s - loss: 27634.4121 - val_loss: 212605.2812 - 377ms/epoch - 5ms/step
# INFO:tensorflow:Assets written to: ONI_S1M2V2_MLPwoFE_90\assets
# 76/76 [==============================] - 0s 2ms/step
# Onion / MLP / Model90 Training Result
# 7/7 [==============================] - 0s 2ms/step
#  40%|█████████████████████████████████▌                                                  | 2/5 [00:18<00:26,  8.76s/it]
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 366)               134322
#
#  dropout_14 (Dropout)        (None, 366)               0
#
#  dense_22 (Dense)            (None, 732)               268644
#
#  dropout_15 (Dropout)        (None, 732)               0
#
#  dense_23 (Dense)            (None, 1)                 733
#
# =================================================================
# Total params: 403,699
# Trainable params: 403,699
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 73/73 - 1s - loss: 300032.9375 - val_loss: 125380.0703 - 724ms/epoch - 10ms/step
# Epoch 2/200
# 73/73 - 0s - loss: 125789.7969 - val_loss: 91182.4766 - 333ms/epoch - 5ms/step
# Epoch 3/200
# 73/73 - 0s - loss: 78882.6562 - val_loss: 86623.0859 - 328ms/epoch - 4ms/step
# Epoch 4/200
# 73/73 - 0s - loss: 62277.0508 - val_loss: 86475.5547 - 374ms/epoch - 5ms/step
# Epoch 5/200
# 73/73 - 0s - loss: 56552.3555 - val_loss: 92877.0938 - 300ms/epoch - 4ms/step
# Epoch 6/200
# 73/73 - 0s - loss: 50926.3320 - val_loss: 129675.5234 - 338ms/epoch - 5ms/step
# Epoch 7/200
# 73/73 - 0s - loss: 45164.6289 - val_loss: 151569.6250 - 326ms/epoch - 4ms/step
# Epoch 8/200
# 73/73 - 0s - loss: 40015.4453 - val_loss: 167199.4688 - 303ms/epoch - 4ms/step
# Epoch 9/200
# 73/73 - 0s - loss: 36967.2500 - val_loss: 204771.7188 - 315ms/epoch - 4ms/step
# Epoch 10/200
# 73/73 - 0s - loss: 32652.8105 - val_loss: 223351.4531 - 333ms/epoch - 5ms/step
# Epoch 11/200
# 73/73 - 0s - loss: 30009.0605 - val_loss: 269842.1562 - 307ms/epoch - 4ms/step
# Epoch 12/200
# 73/73 - 0s - loss: 28205.4082 - val_loss: 263868.5312 - 303ms/epoch - 4ms/step
# Epoch 13/200
# 73/73 - 0s - loss: 23000.9629 - val_loss: 266507.7188 - 299ms/epoch - 4ms/step
# Epoch 14/200
# 73/73 - 0s - loss: 19970.4961 - val_loss: 292729.0625 - 312ms/epoch - 4ms/step
# INFO:tensorflow:Assets written to: ONI_S1M2V2_MLPwoFE_180\assets
# 73/73 [==============================] - 0s 2ms/step
# Onion / MLP / Model180 Training Result
# 7/7 [==============================] - 0s 2ms/step
#  60%|██████████████████████████████████████████████████▍                                 | 3/5 [00:24<00:15,  7.65s/it]
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 366)               134322
#
#  dropout_16 (Dropout)        (None, 366)               0
#
#  dense_25 (Dense)            (None, 732)               268644
#
#  dropout_17 (Dropout)        (None, 732)               0
#
#  dense_26 (Dense)            (None, 1)                 733
#
# =================================================================
# Total params: 403,699
# Trainable params: 403,699
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 70/70 - 1s - loss: 297922.3125 - val_loss: 129884.4844 - 755ms/epoch - 11ms/step
# Epoch 2/200
# 70/70 - 0s - loss: 131880.4062 - val_loss: 79357.5391 - 331ms/epoch - 5ms/step
# Epoch 3/200
# 70/70 - 0s - loss: 84076.2578 - val_loss: 74518.3984 - 350ms/epoch - 5ms/step
# Epoch 4/200
# 70/70 - 0s - loss: 65118.7812 - val_loss: 78858.9688 - 327ms/epoch - 5ms/step
# Epoch 5/200
# 70/70 - 0s - loss: 60132.7891 - val_loss: 82046.3438 - 332ms/epoch - 5ms/step
# Epoch 6/200
# 70/70 - 0s - loss: 56398.3242 - val_loss: 84495.8125 - 291ms/epoch - 4ms/step
# Epoch 7/200
# 70/70 - 0s - loss: 51272.7305 - val_loss: 106094.5391 - 311ms/epoch - 4ms/step
# Epoch 8/200
# 70/70 - 0s - loss: 43879.4766 - val_loss: 171476.8750 - 292ms/epoch - 4ms/step
# Epoch 9/200
# 70/70 - 0s - loss: 38082.5391 - val_loss: 179833.5000 - 314ms/epoch - 4ms/step
# Epoch 10/200
# 70/70 - 0s - loss: 32222.8711 - val_loss: 201708.0156 - 319ms/epoch - 5ms/step
# Epoch 11/200
# 70/70 - 0s - loss: 28662.9160 - val_loss: 220529.5469 - 290ms/epoch - 4ms/step
# Epoch 12/200
# 70/70 - 0s - loss: 24438.3301 - val_loss: 245267.4219 - 294ms/epoch - 4ms/step
# Epoch 13/200
# 70/70 - 0s - loss: 21206.9531 - val_loss: 235051.2031 - 304ms/epoch - 4ms/step
# INFO:tensorflow:Assets written to: ONI_S1M2V2_MLPwoFE_270\assets
# 70/70 [==============================] - 0s 2ms/step
# Onion / MLP / Model270 Training Result
# 7/7 [==============================] - 0s 2ms/step
#  80%|███████████████████████████████████████████████████████████████████▏                | 4/5 [00:30<00:06,  6.97s/it]
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_27 (Dense)            (None, 366)               134322
#
#  dropout_18 (Dropout)        (None, 366)               0
#
#  dense_28 (Dense)            (None, 732)               268644
#
#  dropout_19 (Dropout)        (None, 732)               0
#
#  dense_29 (Dense)            (None, 1)                 733
#
# =================================================================
# Total params: 403,699
# Trainable params: 403,699
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 67/67 - 1s - loss: 277051.8125 - val_loss: 179750.4688 - 723ms/epoch - 11ms/step
# Epoch 2/200
# 67/67 - 0s - loss: 114069.3516 - val_loss: 161283.3125 - 308ms/epoch - 5ms/step
# Epoch 3/200
# 67/67 - 0s - loss: 72422.7422 - val_loss: 114298.3594 - 303ms/epoch - 5ms/step
# Epoch 4/200
# 67/67 - 0s - loss: 60455.5586 - val_loss: 97668.3125 - 344ms/epoch - 5ms/step
# Epoch 5/200
# 67/67 - 0s - loss: 56647.4453 - val_loss: 100502.3828 - 302ms/epoch - 5ms/step
# Epoch 6/200
# 67/67 - 0s - loss: 49138.6133 - val_loss: 102189.7500 - 311ms/epoch - 5ms/step
# Epoch 7/200
# 67/67 - 0s - loss: 42110.2188 - val_loss: 80131.1016 - 318ms/epoch - 5ms/step
# Epoch 8/200
# 67/67 - 0s - loss: 37486.6484 - val_loss: 63645.6484 - 273ms/epoch - 4ms/step
# Epoch 9/200
# 67/67 - 0s - loss: 32852.0469 - val_loss: 45381.2578 - 308ms/epoch - 5ms/step
# Epoch 10/200
# 67/67 - 0s - loss: 25321.9102 - val_loss: 45517.1562 - 304ms/epoch - 5ms/step
# Epoch 11/200
# 67/67 - 0s - loss: 19495.6895 - val_loss: 49200.9922 - 294ms/epoch - 4ms/step
# Epoch 12/200
# 67/67 - 0s - loss: 17114.1621 - val_loss: 30547.6348 - 318ms/epoch - 5ms/step
# Epoch 13/200
# 67/67 - 0s - loss: 14049.1396 - val_loss: 29487.0215 - 282ms/epoch - 4ms/step
# Epoch 14/200
# 67/67 - 0s - loss: 12473.6680 - val_loss: 24681.2402 - 303ms/epoch - 5ms/step
# Epoch 15/200
# 67/67 - 0s - loss: 11344.5703 - val_loss: 35068.5508 - 296ms/epoch - 4ms/step
# Epoch 16/200
# 67/67 - 0s - loss: 10793.5850 - val_loss: 36653.2695 - 285ms/epoch - 4ms/step
# Epoch 17/200
# 67/67 - 0s - loss: 10072.4854 - val_loss: 35861.5586 - 301ms/epoch - 4ms/step
# Epoch 18/200
# 67/67 - 0s - loss: 10048.5859 - val_loss: 45374.5195 - 320ms/epoch - 5ms/step
# Epoch 19/200
# 67/67 - 0s - loss: 9206.2285 - val_loss: 44443.8438 - 315ms/epoch - 5ms/step
# Epoch 20/200
# 67/67 - 0s - loss: 8881.0312 - val_loss: 59830.4609 - 285ms/epoch - 4ms/step
# Epoch 21/200
# 67/67 - 0s - loss: 8432.5361 - val_loss: 53649.0000 - 300ms/epoch - 4ms/step
# Epoch 22/200
# 67/67 - 0s - loss: 8575.2988 - val_loss: 44210.4570 - 306ms/epoch - 5ms/step
# Epoch 23/200
# 67/67 - 0s - loss: 8180.2573 - val_loss: 49465.6289 - 279ms/epoch - 4ms/step
# Epoch 24/200
# 67/67 - 0s - loss: 8886.3301 - val_loss: 48399.1719 - 314ms/epoch - 5ms/step
# INFO:tensorflow:Assets written to: ONI_S1M2V2_MLPwoFE_365\assets
# 67/67 [==============================] - 0s 2ms/step
# Onion / MLP / Model365 Training Result
# 7/7 [==============================] - 0s 2ms/step
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:39<00:00,  7.97s/it]

# %% [markdown]
# # MLP without FE / Visualization

# %%
for i in range(0, NSEL):
    
    print(f'Model{SELECTED[i]} Results\n')

    plot_data = pd.DataFrame([y_test.values, pred[i]]).T
    date_label = pd.date_range(start=x_test.index[0], end=x_test.index[-1], freq='D')
    
    fig, ax = plt.subplots(figsize=(15,6))
        
    plot_data.columns = ['actual','pred']
    ax.plot(date_label, plot_data)
    
    plt.title(PDNAME + ' / ' + MDCODE + ' / Model ' + str(SELECTED[i]) + ' Test Result', fontsize=14)
    plt.xlabel('Date', fontsize=10)
    plt.ylabel('Price', fontsize=10)
    
    dateFmt = mdates.DateFormatter('%y-%m-%d')
    ax.xaxis.set_major_formatter(dateFmt)
    
    plt.show()
    plt.clf()
    
    MAPE = mean_absolute_percentage_error(y_test.values.flatten(), pred[i])*100
    print(f'MAPE={MAPE}')

    RMSE = np.sqrt(mean_squared_error(y_test.values.flatten(), pred[i]))
    print(f'RMSE={RMSE}\n\n\n')
# Out:
# Model30 Results
# MAPE=25.505022348385303
# RMSE=229.3352867308765
#
#
#
# Model90 Results
# MAPE=60.99566040999734
# RMSE=391.6043481371344
#
#
#
# Model180 Results
# MAPE=51.7307596872104
# RMSE=294.0672558190599
#
#
#
# Model270 Results
# MAPE=48.1521144244566
# RMSE=272.98059653000024
#
#
#
# Model365 Results
# MAPE=26.30857425597463
# RMSE=157.1026349765038
